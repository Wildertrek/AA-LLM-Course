# %% [markdown]
# # AutoGen vs. LangChain Comparison Table
#
# **overall comparison** between **AutoGen and LangChain ecosystems**, highlighting their **strengths, weaknesses, and ideal use cases**. This includes a detailed **analysis table** to help choose between the two frameworks.
#
# ---
#
# ## **AutoGen vs. LangChain: Ecosystem Overview**
# ### **AutoGen Ecosystem**
# - **Focus:** **Multi-agent collaboration, autonomous workflows, and agent-driven decision-making.**
# - **Strengths:**
#   - Supports **multi-agent coordination** for solving **complex tasks**.
#   - **Event-driven and asynchronous** execution for high-performance, parallelized workflows.
#   - **Cross-language support** (Python, .NET, expanding).
#   - **Observability built-in** (telemetry, debugging, OpenTelemetry integration).
#   - **No-code UI (AutoGen Studio)** for agent-based orchestration.
#   - **Enterprise-friendly** with structured agent execution models (**Magentic-One**).
# - **Weaknesses:**
#   - **More complex setup** compared to LangChain’s simpler “plug and play” approach.
#   - **Less mature than LangChain** in terms of retrieval-augmented generation (RAG) integrations.
#   - **Smaller ecosystem** of community-contributed extensions and integrations.
#
# ### **LangChain Ecosystem**
# - **Focus:** **LLM-powered applications, Retrieval-Augmented Generation (RAG), and orchestration for AI workflows.**
# - **Strengths:**
#   - **Rich ecosystem** with extensive integrations (OpenAI, Anthropic, Pinecone, Weaviate, etc.).
#   - **Simpler, modular approach** to LLM application development.
#   - **Optimized for RAG use cases** (retrieval-based workflows with vector DBs).
#   - **LangGraph for complex execution control**, enabling multi-step workflows.
#   - **LangSmith for evaluation and monitoring** of LLM performance.
#   - **Wide adoption & community support** in AI/ML development.
# - **Weaknesses:**
#   - **Synchronous execution model** (less suited for event-driven, asynchronous workflows).
#   - **No built-in UI** for multi-agent workflows (LangGraph Studio is more visualization-oriented).
#   - **Limited agent collaboration** (requires manual implementation of multi-agent reasoning).
#
# ---
#
# ## **Comparison Table: AutoGen vs. LangChain Ecosystems**
# | **Feature**                      | **AutoGen Ecosystem**                                       | **LangChain Ecosystem**                                  |
# |----------------------------------|------------------------------------------------------------|---------------------------------------------------------|
# | **Primary Focus**                 | Multi-agent collaboration and AI automation               | LLM-based application development (chatbots, RAG, etc.) |
# | **Execution Model**               | **Event-driven, asynchronous** agent workflows           | **Synchronous, sequential workflows**                  |
# | **Multi-Agent Support**           | **First-class support** for autonomous AI agents         | Possible but requires **manual orchestration**          |
# | **Observability**                 | **Built-in debugging, logging, and telemetry**           | Requires **LangSmith for tracing and monitoring**       |
# | **Retrieval-Augmented Generation (RAG)** | Limited native RAG support but **can integrate external tools** | **First-class RAG support** (LangChain’s primary strength) |
# | **Extensibility**                 | Modular agents, memory, and tools with **plugin support** | **Massive ecosystem** with numerous **pre-built integrations** |
# | **UI & Developer Experience**     | **AutoGen Studio (low-code UI)** for workflow design     | **No UI for orchestration**, but LangGraph Studio for visualization |
# | **Cross-Language Support**        | Python, .NET (expanding to more)                         | Primarily Python                                        |
# | **Tool & API Integrations**       | Extensible, but **fewer pre-built integrations**         | **Extensive integrations** (vector DBs, APIs, models, etc.) |
# | **Orchestration Capabilities**    | **Magentic-One** for structured agent execution         | **LangGraph** for directed acyclic graph workflows     |
# | **Ease of Use**                   | More complex, requires defining agent roles             | Easier to use for standard LLM applications            |
# | **Community & Adoption**          | Growing but smaller ecosystem                           | Large community with **extensive industry adoption**   |
# | **Best for**                      | **Autonomous AI agents, task delegation, automation**    | **RAG, chatbot development, LLM-powered applications** |
#
# ---
#
# ## **Choosing the Right Framework: When to Use AutoGen vs. LangChain**
# | **Use Case**                                         | **Best Choice**       | **Why?** |
# |------------------------------------------------------|----------------------|-----------|
# | **Multi-agent collaboration (e.g., research, coding, automation)** | **AutoGen** | Built-in support for **multiple AI agents coordinating together**. |
# | **Retrieval-Augmented Generation (RAG) systems** (QA bots, enterprise search) | **LangChain** | Strong **vector database and retrieval integrations**. |
# | **Chatbots & conversational AI**                    | **LangChain** | LangChain’s **LLM and chat model abstractions** make it easier. |
# | **Event-driven AI workflows** (e.g., real-time decision-making) | **AutoGen** | AutoGen supports **asynchronous, event-driven execution**. |
# | **Autonomous business process automation**          | **AutoGen** | Multi-agent **task delegation** is a built-in feature. |
# | **LLM evaluation & monitoring**                     | **LangSmith** (LangChain) | LangSmith provides **structured LLM evaluation tools**. |
# | **Agent-based coding assistants** (e.g., multi-agent code generation) | **AutoGen** | AutoGen excels in **agent collaboration for coding tasks**. |
# | **Enterprise-grade AI deployments**                 | **AutoGen** | Supports **structured agent execution, observability, and compliance**. |
# | **Single-agent AI applications**                    | **LangChain** | Simpler approach for **LLM-based applications**. |
# | **Graph-based execution control (DAG workflows)**   | **LangGraph (LangChain)** | LangGraph provides **node-and-edge execution control**. |
#
# ---
#
# ## **Final Thoughts**
# - If you need **multi-agent collaboration, event-driven workflows, and AI task delegation**, **AutoGen** is the better choice.
# - If you’re building **retrieval-based AI applications, chatbots, and structured LLM workflows**, **LangChain** is a better fit.
# - **LangChain + LangGraph + LangSmith** provides a **great combination for LLM orchestration and monitoring**, while **AutoGen + Magentic-One** is excellent for **autonomous AI workflows**.
#
# Both frameworks **complement** each other and **can be integrated together**, depending on your AI system’s needs.

# %% [markdown]
# ### **Best AI Stack for a MEAN Stack + Multi-Database Ecosystem**
# Since company A uses a **MEAN stack** (MongoDB, Express.js, Angular, Node.js) and supports **multiple databases** (**MongoDB, PostgreSQL, Neo4j, OpenSearch, HyperLedger**), the **best AI stack** will depend on **how AI agents interact with the existing infrastructure**.
#
# ### **AutoGen vs. LangChain for Your Stack**
# | **Factor**                           | **AutoGen**                                        | **LangChain**                                      | **Best for Your Company?** |
# |--------------------------------------|---------------------------------------------------|--------------------------------------------------|---------------------------|
# | **MongoDB Integration**              | Moderate support (via plugins)                   | **First-class support** (retrieval + vector storage) | **LangChain** |
# | **PostgreSQL Support**               | Limited direct support                           | **Well-supported via PGVector for AI retrieval** | **LangChain** |
# | **Neo4j (Graph DB)**                 | Some support via custom agents                   | **Better support with LangChain + Graph RAG**    | **LangChain** |
# | **OpenSearch (Search & Retrieval)**  | Possible via API calls                           | **Well-integrated for RAG**                      | **LangChain** |
# | **HyperLedger (Blockchain/Smart Contracts)** | Limited agent support, but custom integrations possible | Limited built-in support, can be integrated manually | **Custom Implementation Needed** |
# | **Event-Driven & Multi-Agent AI**    | **Strong first-class support**                   | Requires manual orchestration                    | **AutoGen** |
# | **LLM + RAG Capabilities**           | Moderate (retrieval possible but not native)     | **Highly optimized for RAG & retrieval workflows** | **LangChain** |
# | **Scalability for AI Workflows**     | **Asynchronous, scalable agent execution**       | Synchronous (requires LangGraph for complexity) | **AutoGen** (if using multi-agent) |
# | **Ease of Deployment in Node.js**    | Python-based (but APIs can be wrapped for Node)  | Python-based (but better Node.js libraries available) | **LangChain** |
#
# ### **Recommendation Based on Your Stack**
# 1. **If you need Retrieval-Augmented Generation (RAG) with your databases**, **LangChain** is the best option because:
#    - MongoDB, PostgreSQL, OpenSearch, and Neo4j are **natively supported**.
#    - RAG pipelines are **first-class** and integrate well with vector databases.
#    - LangChain has **better documentation & examples** for retrieval-based applications.
#
# 2. **If you want autonomous AI agents that work asynchronously across your stack**, **AutoGen** is better because:
#    - It supports **multi-agent systems** that can interact dynamically.
#    - It enables **event-driven workflows** (which could work well with HyperLedger smart contracts).
#    - AutoGen can be configured to interact with your databases **via custom tools & plugins**.
#
# 3. **For a hybrid approach**, you can:
#    - Use **LangChain for retrieval and database interactions**.
#    - Use **AutoGen for orchestration & multi-agent collaboration**.

# %% [markdown]
# A **hybrid AI architecture blueprint** for integrating **LangChain + AutoGen** with MongoDB, PostgreSQL, Neo4j, OpenSearch, and HyperLedger. 🚀
#
# ### **Hybrid AI Architecture Blueprint: LangChain + AutoGen for a MEAN Stack**
# This architecture will leverage **LangChain for Retrieval-Augmented Generation (RAG) and database integration** while **AutoGen handles multi-agent AI workflows, automation, and decision-making**.
#
# ---
#
# ## **📌 Overview of the Hybrid AI Stack**
# | **Layer**          | **Technology**                 | **Role in AI System** |
# |--------------------|--------------------------------|-----------------------|
# | **Frontend**      | **Angular (MEAN stack)**       | User interface for interacting with AI |
# | **Backend**       | **Node.js + Express.js**       | API endpoints for handling AI agent and LLM requests |
# | **AI Agents**     | **AutoGen**                    | Multi-agent AI collaboration, automation, task delegation |
# | **LLM Orchestration** | **LangChain + LangGraph**   | Query optimization, reasoning, and structured workflows |
# | **RAG Engine**    | **LangChain + OpenSearch, MongoDB, PostgreSQL** | Indexing, embedding retrieval, and document search |
# | **Knowledge Graph** | **Neo4j + LangChain GraphRAG** | Graph-based knowledge extraction and relationships |
# | **Blockchain / Security** | **HyperLedger**         | Smart contracts, decentralized AI governance |
# | **Observability** | **AutoGen (Telemetry) + LangSmith** | AI performance monitoring and debugging |
#
# ---
#
# ## **🔹 High-Level Architecture Diagram**
# ```
# +-------------------------------------------------------------+
# |                     Frontend (Angular)                      |
# +-------------------------------------------------------------+
#         ⬇  User Queries / Inputs  ⬇
# +-------------------------------------------------------------+
# |                   Backend (Node.js + Express.js)            |
# |           - API Gateway to AI Components                    |
# |           - Middleware for RAG and Agent Interactions       |
# +-------------------------------------------------------------+
#         ⬇                           ⬇
# +----------------------------+    +---------------------------------+
# |        LangChain (RAG)      |    |        AutoGen (AI Agents)      |
# |  - Query Processing         |    |  - Multi-agent coordination     |
# |  - Vector Search (MongoDB)  |    |  - Event-driven task execution  |
# |  - Document Indexing (OS)   |    |  - Asynchronous decision-making |
# |  - GraphRAG (Neo4j)         |    |  - API / Tool Calls (HyperLedger)|
# +----------------------------+    +---------------------------------+
#         ⬇                           ⬇
# +------------------------------------------------------------------+
# |                        Data Layer                               |
# |  - MongoDB (Vector Storage)  - PostgreSQL (Tabular Data)        |
# |  - Neo4j (Knowledge Graphs)  - OpenSearch (Document Retrieval)  |
# |  - HyperLedger (Blockchain)                                      |
# +------------------------------------------------------------------+
# ```
#
# ---
#
# ## **🛠️ Key AI Components and How They Work Together**
# | **Component**             | **Technology**      | **Purpose** |
# |--------------------------|--------------------|-------------|
# | **User Interface**       | Angular (MEAN)    | Web-based AI application |
# | **Backend API**          | Node.js + Express | Manages interactions between UI, LangChain, and AutoGen |
# | **Multi-Agent AI**       | AutoGen           | Agents collaborate to solve tasks dynamically |
# | **LLM Query Processing** | LangChain         | Orchestrates LLM calls and prompt engineering |
# | **Retrieval-Augmented Generation (RAG)** | LangChain + OpenSearch + MongoDB | Enhances AI responses with factual knowledge |
# | **Graph-Based Reasoning** | LangChain + Neo4j | AI can perform graph-based search and knowledge linking |
# | **Smart Contracts**      | HyperLedger       | Enables blockchain-based agent transactions |
# | **Observability**        | AutoGen (Telemetry) + LangSmith | Monitors AI agent performance and LLM responses |
#
# ---
#
# ## **🔄 Workflow Example: AI-Powered Research Assistant**
# ### **🔹 Use Case: AI Agent Generates an Enterprise Knowledge Graph**
# 1. **User requests a summary of internal documents** (Angular UI → Express API).
# 2. The **request is sent to AutoGen**, where agents collaborate to:
#    - Retrieve structured data from PostgreSQL.
#    - Extract insights from **MongoDB’s vector store** (embedded documents).
#    - Perform **graph reasoning with Neo4j** (connecting related concepts).
# 3. AutoGen **calls LangChain’s RAG engine** to:
#    - **Query OpenSearch** for the most relevant documents.
#    - Generate **context-aware responses** using LLMs.
# 4. The **response is validated** by an AutoGen verification agent.
# 5. If blockchain security is required, **HyperLedger smart contracts** log the request.
# 6. The **final AI-generated knowledge graph** is returned to the frontend.
#
# ---
#
# ## **🛠️ Deployment Strategy**
# | **Component** | **Deployment Mode** |
# |--------------|--------------------|
# | **Frontend (Angular)** | Deployed via Node.js with Nginx |
# | **Backend (Node.js + Express.js)** | Runs as a containerized microservice (Podman, Docker, or OpenShift) |
# | **LangChain (RAG Engine)** | Hosted as a Python-based API microservice |
# | **AutoGen (AI Agents)** | Runs in a Kubernetes-based containerized environment |
# | **Databases (MongoDB, PostgreSQL, Neo4j, OpenSearch, HyperLedger)** | Hosted in a distributed cloud or on-prem setup |
#
# ---
#
# ## **🚀 Why This Hybrid Approach Works for Your MEAN Stack**
# ✔ **Optimized for MongoDB, PostgreSQL, and OpenSearch:** LangChain is **great for RAG**, while AutoGen enables **multi-agent intelligence**.
# ✔ **Agentic AI for Asynchronous Workflows:** AutoGen can **automate decision-making, task delegation, and reasoning**.
# ✔ **Neo4j + GraphRAG for Knowledge Graphs:** AI agents **use graph reasoning** to improve AI responses.
# ✔ **Blockchain AI Governance:** HyperLedger **logs AI decisions** for compliance and auditing.
# ✔ **Future-Proof & Scalable:** Works with **MEAN stack, microservices, and containerized environments**.
#
# ---
#
# ## **Next Steps**
# Would you like:
# 1. **A sample implementation (LangChain + AutoGen + MongoDB RAG pipeline)?**
# 2. **A step-by-step setup guide for integrating this with your MEAN stack?**
# 3. **A notebook demo for AutoGen multi-agent orchestration with LangChain retrieval?** 🚀

# %%
#pip install autogen

# %%
import os
import asyncio
from dotenv import load_dotenv
from autogen import AssistantAgent, UserProxyAgent, config_list_from_json, OpenAIWrapper

import autogen
from langchain.vectorstores import FAISS
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.llms import OpenAI
from langchain.chains import RetrievalQA

# Load environment variables from .env file
load_dotenv()

# Retrieve the OpenAI API key from environment variables
openai_api_key = os.getenv("OPENAI_API_KEY")
if not openai_api_key:
    raise ValueError("OPENAI_API_KEY not found in environment variables. Check your .env file.")

# Initialize the OpenAI model client with the API key
model_client = OpenAIWrapper(model="gpt-4o", api_key=openai_api_key)

# Step 1: Load and Index Documents


loader = TextLoader("sample_docs.txt")  # Load sample documents
raw_documents = loader.load()
if not raw_documents:
    raise ValueError("No documents found in sample_docs.txt. Ensure it has valid content.")  # Assuming you have a sample document file
raw_documents = loader.load()

text_splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=50)
documents = text_splitter.split_documents(raw_documents)

embeddings = OpenAIEmbeddings()
vector_store = FAISS.from_documents(documents, embeddings)
retriever = vector_store.as_retriever()

qa_chain = RetrievalQA.from_chain_type(
    llm=OpenAI(), chain_type="stuff", retriever=retriever
)

# Step 2: Define AutoGen Agents


retrieval_agent = AssistantAgent(
    name="retrieval_agent",
    system_message="You retrieve relevant documents from the LangChain RAG pipeline.",
    function_map={"retrieve": lambda query: qa_chain.invoke(query)},
)

research_agent = UserProxyAgent(
    name="research_agent",
    system_message="You analyze research topics and request relevant documents from the retrieval agent.",
    
)

validation_agent = AssistantAgent(
    name="validation_agent",
    system_message="You verify the accuracy and relevance of retrieved documents.",
    function_map={"validate": lambda response: f'Validated response: {response}'},
)

# Step 3: Multi-Agent Orchestration
def run_multi_agent_query(query):
    response = retrieval_agent.function_map["retrieve"](query)
    validation_response = validation_agent.function_map["validate"](response)
    return validation_response

# Example Usage
query = "How does AutoGen integrate with LangChain?"
validated_response = run_multi_agent_query(query)
print("Final Validated Response:", validated_response)

# Define the main asynchronous function
async def main():
    # Define the user's input
    user_input = "How can I integrate AutoGen agents into a LangChain retrieval pipeline?"
    
    # Send the user's input to the assistant agent and get the response
    response = retrieval_agent.function_map["retrieve"](user_input)
    
    # Print the assistant's response
    print("Assistant:", response["result"])

# Run the main function
await main()
# Out:
# /tmp/ipykernel_635931/3331672355.py:39: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings()
# /tmp/ipykernel_635931/3331672355.py:44: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAI``.
#   llm=OpenAI(), chain_type="stuff", retriever=retriever
# ...

# %%
#testing
import os
import asyncio
from dotenv import load_dotenv
import autogen
from autogen import AssistantAgent, UserProxyAgent

# LangChain imports (use newer versions)
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings, OpenAI # Use langchain_openai
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains import RetrievalQA

# Load environment variables
load_dotenv()

# Retrieve the OpenAI API key from environment variables
openai_api_key = os.getenv("OPENAI_API_KEY")
if not openai_api_key:
    raise ValueError("OPENAI_API_KEY not found in environment variables. Check your .env file.")

# --- Define AutoGen LLM Configuration Directly ---
config_list = [
    {
        "model": "gpt-4o",  # Or whichever model you want to use
        "api_key": openai_api_key,
        # Add other fields if needed (e.g., base_url for Azure/local)
        # "base_url": "...",
        # "api_type": "...",
        # "api_version": "..."
    }
]

# You can add more dictionaries here for fallbacks or different models if needed
# config_list.append({ ... })

# Now use this config_list when creating your agents
llm_config = {"config_list": config_list, "cache_seed": 42} # Example usage

# Example Agent Initialization:
# retrieval_assistant = AssistantAgent(
#     name="RetrievalAssistant",
#     system_message="...",
#     llm_config=llm_config, # Pass the config here
# )
# research_agent_proxy = UserProxyAgent(
#     name="ResearchAgentProxy",
#     human_input_mode="NEVER",
#     llm_config=llm_config, # Pass the config here
#     function_map={ ... }
# )

# --- LangChain RAG Setup ---
try:
    loader = TextLoader("sample_docs.txt")
    raw_documents = loader.load()
    if not raw_documents:
         print("Warning: No documents found in sample_docs.txt.")
         # Handle case with no docs if necessary, maybe skip RAG setup
    else:
        text_splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=50)
        documents = text_splitter.split_documents(raw_documents)

        embeddings = OpenAIEmbeddings(openai_api_key=openai_api_key) # Pass key if needed
        vector_store = FAISS.from_documents(documents, embeddings)
        retriever = vector_store.as_retriever()

        # Use updated LangChain OpenAI and potentially a better model
        qa_chain = RetrievalQA.from_chain_type(
            llm=OpenAI(temperature=0, openai_api_key=openai_api_key), # Pass key if needed
            chain_type="stuff",
            retriever=retriever,
            return_source_documents=True # Often useful to see retrieved docs
        )
except Exception as e:
    print(f"Error setting up LangChain RAG: {e}")
    qa_chain = None # Ensure qa_chain is defined even on error

# --- Define Retrieval Function ---
# This is the function the agent will call
def retrieve_from_rag(query: str) -> str:
    """Retrieves information from the LangChain RAG pipeline based on the query."""
    if not qa_chain:
        return "RAG system is not available due to an earlier setup error."
    try:
        print(f"\n--- Calling RAG Chain with query: {query} ---")
        response = qa_chain.invoke({"query": query})
        print(f"--- RAG Chain response: {response} ---")
        # Check if the result indicates uncertainty
        if "don't know" in response.get('result', '').lower() or not response.get('result', '').strip():
             # Return a clearer message if RAG didn't find anything useful
             # Optionally include source docs info if available and empty
             source_docs = response.get('source_documents', [])
             if source_docs:
                 return f"I searched the documents, but couldn't find specific information for '{query}'. The closest context retrieved was: {source_docs[0].page_content[:200]}..." # Show snippet
             else:
                 return f"I searched the documents, but couldn't find any relevant information for '{query}'."
        return response['result'] # Return only the text result
    except Exception as e:
        print(f"Error during RAG retrieval: {e}")
        return f"An error occurred while trying to retrieve information: {e}"


# --- Define AutoGen Agents with LLM Config ---

# Assistant responsible for using the RAG tool
retrieval_assistant = AssistantAgent(
    name="RetrievalAssistant",
    system_message="You are an assistant that uses the provided RAG tool to answer questions based on the documents.",
    llm_config=llm_config,
)

# User Proxy Agent - Acts on behalf of the user and executes functions
# Needs function map and configuration to execute function calls
research_agent_proxy = UserProxyAgent(
    name="ResearchAgentProxy",
    human_input_mode="NEVER", # Or "TERMINATE" / "ALWAYS" depending on desired interaction
    max_consecutive_auto_reply=5,
    is_termination_msg=lambda x: x.get("content", "").rstrip().endswith("TERMINATE"),
    code_execution_config=False, # Don't execute arbitrary code blocks
    llm_config=llm_config, # May need LLM to process replies/decide termination
    # Register the function for execution
    function_map={
        "retrieve_from_rag": retrieve_from_rag
    }
)


# --- Register the function with the agents ---
# The User Proxy needs to know about the function to execute it.
# The Assistant needs to know about the function signature to propose calling it.
retrieval_assistant.register_for_llm(name="retrieve_from_rag", description="Retrieves information from the LangChain RAG pipeline based on a query.")(retrieve_from_rag)
research_agent_proxy.register_for_execution(name="retrieve_from_rag")(retrieve_from_rag)


# --- Run the Chat ---
async def run_chat():
    query = "How does AutoGen integrate with LangChain based on the provided documents?"
    # query = "Summarize the main points about LangChain in the document." # Example query relevant to LangChain docs

    print(f"Starting chat with query: {query}")

    # Initiate chat: User Proxy sends message to Retrieval Assistant
    await research_agent_proxy.a_initiate_chat(
        retrieval_assistant,
        message=query
    )

    # You can access the chat history afterwards if needed
    # history = research_agent_proxy.chat_messages[retrieval_assistant]
    # print("\nChat History:")
    # for msg in history:
    #     print(msg)

# Run the main async function
async def main():
    await run_chat()

if __name__ == "__main__":
     # Ensure asyncio event loop is handled correctly if running as script
     # In Jupyter, just `await main()` might be enough
    try:
        asyncio.run(main())
    except RuntimeError as e:
        if "cannot run nested event loops" in str(e):
             print("Skipping asyncio.run() as it seems to be running in an environment like Jupyter.")
             # In Jupyter or similar environments, you might just call await main() directly
             # await main() # Uncomment if needed in Jupyter
        else:
            raise e

# %% [markdown]
# ---
#
# ### **📌 Component Breakdown**
# | **Component**         | **Description**                                    |
# |----------------------|------------------------------------------------|
# | 👤 **User Input**       | User provides a query for information retrieval. |
# | 🔬 **Research Agent**   | Analyzes the query and requests relevant documents. |
# | 🤖 **Retrieval Agent**  | Fetches documents from the LangChain retrieval pipeline. |
# | 🧠 **LangChain RAG Query** | Queries stored embeddings for relevant results. |
# | 🔍 **Retriever**       | Uses FAISS to find relevant document chunks. |
# | 📥 **FAISS Vector Store** | Stores embeddings for efficient retrieval. |
# | 🔢 **Embeddings**      | Converts text into numerical vector representations. |
# | ✂️ **Text Splitter**   | Breaks documents into smaller chunks for indexing. |
# | 📄 **Text Loader**     | Loads documents (e.g., `sample_docs.txt`). |
# | ✅ **Validation Agent** | Validates and ensures retrieved data is accurate. |
# | 📤 **Final Output**    | Displays the validated response. |
#
# ---
#
# ### **🔹 Summary**
# - This pipeline **retrieves documents** from a knowledge base, **processes them using embeddings**, and **validates** the retrieved results before providing a final response.
# - AutoGen agents interact with LangChain’s **RetrievalQA** process to enhance **multi-agent cooperation** in handling queries.

# %%
#pip install --upgrade "autogen[openai]"

# %%
#pip install faiss-cpu

# %%
#pip install networkx

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Define nodes with clearer labels and categories
nodes = {
    "User": "User Input",
    "TextLoader": "Load Documents\n(sample_docs.txt)",
    "TextSplitter": "Split Text into Chunks",
    "Embeddings": "Generate Embeddings\n(OpenAI Embeddings)",
    "FAISS": "Store Embeddings\n(FAISS Vector Store)",
    "Retriever": "Retrieve Relevant Documents",
    "QAChain": "LangChain RAG Query",
    "RetrievalAgent": "Retrieval Agent\n(fetches docs)",
    "ResearchAgent": "Research Agent\n(asks queries)",
    "ValidationAgent": "Validation Agent\n(validates responses)",
    "FinalOutput": "Final Validated Response"
}

# Add nodes to the graph
for node, label in nodes.items():
    G.add_node(node, label=label)

# Define edges to show data flow
edges = [
    ("User", "ResearchAgent"),
    ("ResearchAgent", "RetrievalAgent"),
    ("RetrievalAgent", "QAChain"),
    ("QAChain", "Retriever"),
    ("Retriever", "FAISS"),
    ("FAISS", "Embeddings"),
    ("Embeddings", "TextSplitter"),
    ("TextSplitter", "TextLoader"),
    ("TextLoader", "Retriever"),  # Documents go back into retrieval
    ("QAChain", "ValidationAgent"),
    ("ValidationAgent", "FinalOutput")
]

# Add edges to the graph
G.add_edges_from(edges)

# Define a better layout for readability
pos = {
    "User": (0, 5),
    "ResearchAgent": (2, 5),
    "RetrievalAgent": (4, 5),
    "QAChain": (6, 5),
    "ValidationAgent": (8, 5),
    "FinalOutput": (10, 5),
    
    "TextLoader": (2, 3),
    "TextSplitter": (4, 3),
    "Embeddings": (6, 3),
    "FAISS": (8, 3),
    "Retriever": (5, 4)
}

# Draw the graph with improved spacing
plt.figure(figsize=(12, 6))
nx.draw(G, pos, with_labels=False, node_size=4500, node_color="lightblue", edge_color="gray", font_weight="bold", arrowsize=15)

# Add labels separately for better readability
node_labels = nx.get_node_attributes(G, 'label')
for node, (x, y) in pos.items():
    plt.text(x, y, node_labels[node], fontsize=10, ha='center', va='center', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))

# Show plot
plt.title("AutoGen + LangChain RAG Pipeline (with Embeddings)")
plt.show()

# %% [markdown]
# Our implementation of the **FAISS vector store is in memory**.
#
# ### 🔍 **Explanation**
# The line:
# ```python
# vector_store = FAISS.from_documents(documents, embeddings)
# ```
# creates a **temporary FAISS (Facebook AI Similarity Search) index** stored in memory, meaning it will not persist across different runs of your script.
#
# ### 🔥 **How to Persist the FAISS Index?**
# If you want to save the FAISS index to disk for later reuse, you need to specify a path and use FAISS’s built-in save/load methods.
#
# #### **Saving the FAISS Index**
# ```python
# vector_store.save_local("faiss_index")
# ```
#
# #### **Loading the FAISS Index**
# ```python
# vector_store = FAISS.load_local("faiss_index", embeddings)
# retriever = vector_store.as_retriever()
# ```
#
# ### 🛠 **Key Takeaways**
# 1. **By default, FAISS is an in-memory index.**
# 2. **If you don't save it**, it will be lost when the script stops running.
# 3. **Use `save_local()` and `load_local()` to persist the vector store**.

# %% [markdown]
# We can inspect both the **FAISS vector store contents** and the **embeddings** stored in memory.
#
# ---
#
# ## **1️⃣ View FAISS Vector Store Contents**
# FAISS stores **embeddings** along with their corresponding document metadata. To check what's inside:
#
#
# ---

# %%
# Get the number of vectors stored
print(f"Number of vectors stored: {vector_store.index.ntotal}")

# View stored document metadata
print("Stored metadata:", vector_store.docstore._dict)

# View stored document texts
print("Stored documents:", [doc.page_content for doc in vector_store.docstore._dict.values()])
# Out:
# Number of vectors stored: 6
# ...

# %% [markdown]
# ## **2️⃣ Inspect Embeddings Directly**
# To check what embeddings are being generated from a sample text:

# %%
# Example text to embed
text_sample = "This is a test document."

# Generate an embedding
sample_embedding = embeddings.embed_query(text_sample)

# Print the embedding vector
print("Sample Embedding:", sample_embedding[:100])  # Show first 10 dimensions for readability
print(f"Embedding vector length: {len(sample_embedding)}")  # Check dimensionality
# Out:
# Sample Embedding: [-0.003181147517311214, 0.011063990750583778, -0.004148162764961417, -0.011757574588764017, -0.000952843661744372, 0.010843911782860314, -0.010497119863770195, -0.005195207257307961, -0.010056960997000724, -0.026022720226040755, 0.020367346034089667, 0.022568139436614485, -0.007489368073173405, 0.01720620635182147, -0.0060555173886345254, 0.019046870365103795, 0.020967562924590552, -0.015832377076935914, 0.007689440370007033, -0.01827325798071912, -0.0007385997207972543, -0.006519017992323836, -0.011063990750583778, 0.01772639469611792, -0.02216799670559232, -0.0031094550063673334, 0.014511901407950042, -0.029984149095643464, 0.018620048968486697, -0.00799621708467239, 0.010163666346154997, -0.019353648011091695, -0.003758022205230987, -0.024315436502217454, -0.005652038660259812, 0.0037780293417820953, -0.005528660774923159, -0.029530650896076524, 0.018860136469745086, -0.01668601800752502, 0.007449353800071189, 0.01246449589709663, -0.0008432208283057542, -0.01067
# ...

# %% [markdown]
# ## **3️⃣ Retrieve and Inspect Stored Embeddings**
# If you want to **retrieve stored embeddings and their corresponding texts**:
#
# ### 🔍 **Key Takeaways**
# - `vector_store.index.ntotal` **shows the number of stored embeddings.**
# - `vector_store.docstore._dict` **retrieves the stored text.**
# - `embeddings.embed_query("text")` **generates an embedding vector.**
# - `vector_store.index.reconstruct_n(0, vector_store.index.ntotal)` **retrieves embeddings in FAISS.**
#
# Would you like help visualizing the embeddings or checking similarity between them? 🚀

# %%
# Get stored embeddings from FAISS
import numpy as np

stored_embeddings = np.array(vector_store.index.reconstruct_n(0, vector_store.index.ntotal))
print(f"Stored Embeddings Shape: {stored_embeddings.shape}")  # Should be (# docs, embedding_dim)
# Out:
# Stored Embeddings Shape: (6, 1536)
