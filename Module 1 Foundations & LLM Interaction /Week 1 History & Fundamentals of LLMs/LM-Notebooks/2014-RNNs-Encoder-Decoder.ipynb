# %% [markdown]
# # 2014 - RNNs in Encoder-Decoder Architectures
#
# [2014 RNNs in Encoder-Decoder architectures](https://en.wikipedia.org/wiki/Recurrent_neural_network)
# RNNs were a significant advancement, capable of computing document embeddings and adding word context. They grew to include LSTM (1997) for long-term dependencies and Bidirectional RNN (1997) for context understanding. Encoder-Decoder RNNs (2014) improved on this method.
#
# ```NOTE TOSELF: Create an LSTM notebook and add the architecture for RNNs also add Vanishing gradients notebook or add to LSTM notebook.```
#
# [Fundamentals of Recurrent Neural Network (RNN) and Long Short-Term Memory (LSTM) Network](https://arxiv.org/abs/1808.03314)
#
# In this notebook, we will explore the concept of Recurrent Neural Networks (RNNs) and how they are used in Encoder-Decoder architectures, which significantly improved the ability to model sequences and context in text data. We'll implement a basic Encoder-Decoder model using RNNs for sequence-to-sequence tasks.
#
# ### Step-by-Step Explanation:
#
# 1. **Understanding RNNs**: RNNs are a type of neural network designed to handle sequential data by maintaining a hidden state that captures information about previous inputs in the sequence.
# 2. **Encoder-Decoder Architecture**: This architecture consists of two RNNs: an Encoder that processes the input sequence and compresses it into a fixed-length context vector, and a Decoder that generates the output sequence based on this context vector.
# 3. **Training an Encoder-Decoder Model**: We'll train a simple Encoder-Decoder model using a sample dataset.
# 4. **Generating Sequences**: Using the trained model, we will generate sequences to demonstrate how the Encoder-Decoder architecture works.
#
# ### Implementation
#
# #### 1. Install Required Libraries
#
# Before running the code, ensure you have the necessary libraries installed. You can use:
#
# ```bash
# !pip install tensorflow numpy
# ```
#
# #### 2. Import Libraries and Define the Dataset

# %%
#pip install tensorflow numpy

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense

# Define a simple dataset
input_texts = [
    "hello",
    "world",
    "machine",
    "learning",
    "encoder",
    "decoder"
]

output_texts = [
    "hola",
    "mundo",
    "máquina",
    "aprendizaje",
    "codificador",
    "decodificador"
]

# Create character sets
input_characters = sorted(set(''.join(input_texts)))
output_characters = sorted(set(''.join(output_texts)))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(output_characters)

# Create a mapping of characters to integers
input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
output_token_index = dict([(char, i) for i, char in enumerate(output_characters)])

# %% [markdown]
# #### 3. Preprocess the Data

# %%
# Define maximum sequence lengths
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in output_texts])

# Vectorize the input and output texts
encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype='float32')
decoder_input_data = np.zeros((len(output_texts), max_decoder_seq_length, num_decoder_tokens), dtype='float32')
decoder_target_data = np.zeros((len(output_texts), max_decoder_seq_length, num_decoder_tokens), dtype='float32')

for i, (input_text, target_text) in enumerate(zip(input_texts, output_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    for t, char in enumerate(target_text):
        decoder_input_data[i, t, output_token_index[char]] = 1.0
        if t > 0:
            decoder_target_data[i, t - 1, output_token_index[char]] = 1.0

# %% [markdown]
# #### 4. Build the Encoder-Decoder Model

# %%
# Define the Encoder
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder_lstm = LSTM(256, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_inputs)
encoder_states = [state_h, state_c]

# Define the Decoder
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(256, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #### 5. Train the Model

# %%
# Train the model
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=64,
          epochs=100,
          validation_split=0.2)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.1731 - loss: 1.2776 - val_accuracy: 0.1538 - val_loss: 2.4385
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4038 - loss: 1.2682 - val_accuracy: 0.1538 - val_loss: 2.4369
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5962 - loss: 1.2603 - val_accuracy: 0.1538 - val_loss: 2.4353
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6538 - loss: 1.2528 - val_accuracy: 0.2308 - val_loss: 2.4334
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7308 - loss: 1.2452 - val_accuracy: 0.2308 - val_loss: 2.4309
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7500 - loss: 1.2367 - val_accuracy: 0.2308 - val_loss: 2.4276
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6923 - loss: 1.2265 - val_accuracy: 0.2308 - val_loss: 2.4242
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6923 - loss: 1.2124 - val_accuracy: 0.2308 - val_loss: 2.4292
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6731 - loss: 1.1915 - val_accuracy: 0.2692 - val_loss: 2.4710
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6731 - loss: 1.1680 - val_accuracy: 0.2692 - val_loss: 2.5083
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6538 - loss: 1.1553 - val_accuracy: 0.2692 - val_loss: 2.5244
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6538 - loss: 1.1384 - val_accuracy: 0.2692 - val_loss: 2.5323
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6538 - loss: 1.1300 - val_accuracy: 0.2692 - val_loss: 2.5308
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6538 - loss: 1.1181 - val_accuracy: 0.2692 - val_loss: 2.5199
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6538 - loss: 1.1101 - val_accuracy: 0.2692 - val_loss: 2.5264
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6346 - loss: 1.1005 - val_accuracy: 0.2692 - val_loss: 2.5166
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6346 - loss: 1.0913 - val_accuracy: 0.2692 - val_loss: 2.5270
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6346 - loss: 1.0828 - val_accuracy: 0.2692 - val_loss: 2.5211
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6538 - loss: 1.0735 - val_accuracy: 0.2308 - val_loss: 2.5338
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6538 - loss: 1.0664 - val_accuracy: 0.2308 - val_loss: 2.5387
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6538 - loss: 1.0583 - val_accuracy: 0.2308 - val_loss: 2.5407
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6538 - loss: 1.0472 - val_accuracy: 0.2308 - val_loss: 2.5469
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6538 - loss: 1.0445 - val_accuracy: 0.2308 - val_loss: 2.5493
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6731 - loss: 1.0327 - val_accuracy: 0.2308 - val_loss: 2.5526
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6538 - loss: 1.0257 - val_accuracy: 0.2308 - val_loss: 2.5615
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6538 - loss: 1.0146 - val_accuracy: 0.2308 - val_loss: 2.5693
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6346 - loss: 1.0118 - val_accuracy: 0.2308 - val_loss: 2.5710
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6346 - loss: 0.9960 - val_accuracy: 0.2308 - val_loss: 2.5897
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6538 - loss: 1.0067 - val_accuracy: 0.2308 - val_loss: 2.5919
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6346 - loss: 0.9861 - val_accuracy: 0.2308 - val_loss: 2.5944
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6346 - loss: 0.9892 - val_accuracy: 0.2308 - val_loss: 2.5948
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6346 - loss: 0.9666 - val_accuracy: 0.2308 - val_loss: 2.6044
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6731 - loss: 0.9832 - val_accuracy: 0.2308 - val_loss: 2.6165
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6538 - loss: 0.9537 - val_accuracy: 0.2308 - val_loss: 2.5994
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6731 - loss: 0.9749 - val_accuracy: 0.2308 - val_loss: 2.6266
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7115 - loss: 0.9370 - val_accuracy: 0.2308 - val_loss: 2.5981
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6731 - loss: 0.9601 - val_accuracy: 0.2308 - val_loss: 2.6348
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7115 - loss: 0.9166 - val_accuracy: 0.2308 - val_loss: 2.5913
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6346 - loss: 0.9710 - val_accuracy: 0.2308 - val_loss: 2.6227
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7308 - loss: 0.9215 - val_accuracy: 0.2308 - val_loss: 2.6222
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7500 - loss: 0.9020 - val_accuracy: 0.2308 - val_loss: 2.6408
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7500 - loss: 0.8796 - val_accuracy: 0.2308 - val_loss: 2.5980
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6923 - loss: 0.9254 - val_accuracy: 0.2308 - val_loss: 2.6987
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6923 - loss: 0.8684 - val_accuracy: 0.2692 - val_loss: 2.5761
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6346 - loss: 0.9952 - val_accuracy: 0.2308 - val_loss: 2.5732
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7692 - loss: 0.9259 - val_accuracy: 0.2308 - val_loss: 2.6270
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7885 - loss: 0.8774 - val_accuracy: 0.2308 - val_loss: 2.6636
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7692 - loss: 0.8389 - val_accuracy: 0.2308 - val_loss: 2.6535
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7885 - loss: 0.8107 - val_accuracy: 0.2308 - val_loss: 2.6678
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8269 - loss: 0.7940 - val_accuracy: 0.2308 - val_loss: 2.7265
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7308 - loss: 0.7837 - val_accuracy: 0.2692 - val_loss: 2.5911
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6346 - loss: 1.0163 - val_accuracy: 0.2308 - val_loss: 2.5637
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7115 - loss: 0.9313 - val_accuracy: 0.2308 - val_loss: 2.6013
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7692 - loss: 0.8578 - val_accuracy: 0.2308 - val_loss: 2.6610
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8269 - loss: 0.8016 - val_accuracy: 0.2308 - val_loss: 2.6902
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8077 - loss: 0.7585 - val_accuracy: 0.2308 - val_loss: 2.7023
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7885 - loss: 0.7310 - val_accuracy: 0.2308 - val_loss: 2.6393
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7692 - loss: 0.8246 - val_accuracy: 0.2308 - val_loss: 2.8859
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6346 - loss: 0.8403 - val_accuracy: 0.2692 - val_loss: 2.6098
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6346 - loss: 0.9806 - val_accuracy: 0.2308 - val_loss: 2.5699
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7308 - loss: 0.9188 - val_accuracy: 0.2308 - val_loss: 2.5833
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7692 - loss: 0.8678 - val_accuracy: 0.2308 - val_loss: 2.6044
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8077 - loss: 0.8269 - val_accuracy: 0.2308 - val_loss: 2.6257
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8462 - loss: 0.7940 - val_accuracy: 0.2308 - val_loss: 2.6517
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8654 - loss: 0.7614 - val_accuracy: 0.2308 - val_loss: 2.6845
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8654 - loss: 0.7286 - val_accuracy: 0.2308 - val_loss: 2.7098
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8654 - loss: 0.6992 - val_accuracy: 0.2308 - val_loss: 2.7270
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8462 - loss: 0.6772 - val_accuracy: 0.2308 - val_loss: 2.7304
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8654 - loss: 0.6681 - val_accuracy: 0.2308 - val_loss: 2.7727
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8269 - loss: 0.6539 - val_accuracy: 0.2308 - val_loss: 2.6668
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7692 - loss: 0.7520 - val_accuracy: 0.2308 - val_loss: 2.8882
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7500 - loss: 0.6858 - val_accuracy: 0.2308 - val_loss: 2.6315
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7115 - loss: 0.8657 - val_accuracy: 0.2308 - val_loss: 2.6361
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8269 - loss: 0.7489 - val_accuracy: 0.2308 - val_loss: 2.6982
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8462 - loss: 0.6812 - val_accuracy: 0.2308 - val_loss: 2.7760
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8654 - loss: 0.6364 - val_accuracy: 0.2308 - val_loss: 2.7901
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8654 - loss: 0.6156 - val_accuracy: 0.2308 - val_loss: 2.8028
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8462 - loss: 0.6048 - val_accuracy: 0.2308 - val_loss: 2.7681
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8654 - loss: 0.6056 - val_accuracy: 0.2308 - val_loss: 2.8511
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8269 - loss: 0.6030 - val_accuracy: 0.2308 - val_loss: 2.6805
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7692 - loss: 0.7250 - val_accuracy: 0.2308 - val_loss: 2.9747
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.7885 - loss: 0.6499 - val_accuracy: 0.2308 - val_loss: 2.6649
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7500 - loss: 0.8378 - val_accuracy: 0.2308 - val_loss: 2.6419
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8269 - loss: 0.7539 - val_accuracy: 0.2308 - val_loss: 2.6533
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8654 - loss: 0.6997 - val_accuracy: 0.2692 - val_loss: 2.7800
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8269 - loss: 0.6325 - val_accuracy: 0.2308 - val_loss: 2.7655
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8462 - loss: 0.6242 - val_accuracy: 0.2308 - val_loss: 2.9116
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8269 - loss: 0.5927 - val_accuracy: 0.2308 - val_loss: 2.7496
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8269 - loss: 0.6415 - val_accuracy: 0.2308 - val_loss: 2.9163
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8462 - loss: 0.5674 - val_accuracy: 0.2308 - val_loss: 2.7978
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8654 - loss: 0.5954 - val_accuracy: 0.2308 - val_loss: 2.9467
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8269 - loss: 0.5582 - val_accuracy: 0.2308 - val_loss: 2.7335
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8462 - loss: 0.6551 - val_accuracy: 0.2308 - val_loss: 2.9122
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8462 - loss: 0.5511 - val_accuracy: 0.2308 - val_loss: 2.8833
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8654 - loss: 0.5478 - val_accuracy: 0.2308 - val_loss: 2.9503
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8462 - loss: 0.5308 - val_accuracy: 0.2308 - val_loss: 2.7764
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8462 - loss: 0.6156 - val_accuracy: 0.2308 - val_loss: 2.9861
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8462 - loss: 0.5395 - val_accuracy: 0.2308 - val_loss: 2.7590
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8269 - loss: 0.6346 - val_accuracy: 0.2308 - val_loss: 2.9879
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8462 - loss: 0.5271 - val_accuracy: 0.2308 - val_loss: 2.8608

# %% [markdown]
# #### 6. Define Inference Models for Prediction

# %%
# Define the encoder model for inference
encoder_model = Model(encoder_inputs, encoder_states)

# Define the decoder model for inference
decoder_state_input_h = Input(shape=(256,))
decoder_state_input_c = Input(shape=(256,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %% [markdown]
# #### 7. Generate Sequences

# %%
# some decoding errors that I need to fix for this one
def decode_sequence(input_seq):
    # Encode the input as state vectors
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1
    target_seq = np.zeros((1, 1, num_decoder_tokens))

    # Sampling loop for a batch of sequences
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = output_characters[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length or find a stop character
        if len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (length 1)
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]

    return decoded_sentence


# Test the model
for seq_index in range(len(input_texts)):
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input:', input_texts[seq_index])
    print('Decoded:', decoded_sentence)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -
# Input: hello
# Decoded: olaaaaaaaaaaaa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# -
# Input: world
# Decoded: unnaaaaaaaaaaa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# -
# Input: machine
# Decoded: áquinaaaaaaaaa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# -
# Input: learning
# Decoded: prennnaaaaaaaa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# -
# Input: encoder
# Decoded: prnnnaaaaaaaaa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# -
# Input: decoder
# Decoded: unnnaaaaaaaaaa

# %% [markdown]
# ### Explanation of Encoder-Decoder Architectures
#
# #### Recurrent Neural Networks (RNNs)
#
# RNNs are a type of neural network designed to handle sequential data by maintaining a hidden state that captures information about previous inputs in the sequence. However, vanilla RNNs struggle with long-term dependencies due to issues like vanishing gradients, which LSTM and GRU units aim to mitigate. (LOOK UP LSTM, GRU, Vanishing Gradient)
#
# #### Encoder-Decoder Architectures
#
# Encoder-Decoder architectures consist of two main components:
# - **Encoder**: Processes the input sequence and compresses the information into a fixed-length context vector (hidden state).
# - **Decoder**: Takes the context vector and generates the output sequence.
#
# These architectures are widely used in various sequence-to-sequence tasks such as machine translation, text summarization, and conversational modeling.
#
# ### Mathematical Notation
#
# Given a sequence of words $ x_1, x_2, \ldots, x_T $:
# - **Encoder**: The encoder processes each word $ x_t $ and updates its hidden state $ h_t $ using:
#   $$
#   h_t = f(h_{t-1}, x_t)
#   $$
#   Where $ f $ is the RNN function (e.g., LSTM or GRU).
#
# - **Decoder**: The decoder generates each word $ y_t $ in the output sequence using the context vector and the previous hidden state:
#   $$
#   s_t = g(s_{t-1}, y_{t-1}, c)
#   $$
#   Where $ g $ is the RNN function, $ s_t $ is the hidden state of the decoder, and $ c $ is the context vector from the encoder.

# %% [markdown]
# The overall goal of this notebook is to demonstrate the application of Recurrent Neural Networks (RNNs) within an Encoder-Decoder architecture for sequence-to-sequence tasks. Specifically, it showcases how to build and train a basic Encoder-Decoder model using RNNs to translate or map input sequences to output sequences.
#
# ### Summary of the Notebook:
# 1. **Introduction to RNNs and Encoder-Decoder Architecture**: The notebook introduces RNNs and how they are used in Encoder-Decoder architectures for tasks that involve transforming an input sequence into an output sequence, such as translation.
#
# 2. **Creating a Simple Dataset**: A small dataset of simple word pairs is defined, where each input word (e.g., "hello") is mapped to an output word in another language (e.g., "hola"). This serves as a minimal example to train the Encoder-Decoder model.
#
# 3. **Building the Model**: The notebook constructs an Encoder-Decoder model using Long Short-Term Memory (LSTM) units:
#    - **Encoder**: Encodes the input sequence into a fixed-length context vector.
#    - **Decoder**: Decodes this context vector to generate the output sequence.
#
# 4. **Training the Model**: The model is trained on the dataset to learn how to map each input sequence to the corresponding output sequence.
#
# 5. **Generating Sequences**: The trained model is used to generate or predict output sequences for given input sequences, demonstrating how the Encoder-Decoder architecture processes and produces sequences.
#
# ### Key Takeaways:
# - **RNNs for Sequence Modeling**: Showcased how RNNs are effective for handling sequential data by maintaining a hidden state that captures information from previous inputs.
# - **Encoder-Decoder Architecture**: Illustrated how this architecture works for sequence-to-sequence tasks by first encoding an input sequence into a context vector and then decoding this vector to generate an output sequence.
# - **Practical Implementation**: Provided a hands-on example using TensorFlow and Keras to build, train, and use an Encoder-Decoder model for simple word-to-word translation tasks.
#
# This notebook serves as an introductory demonstration of how RNNs in Encoder-Decoder architectures can be applied to tasks such as translation, text summarization, and other sequence transformations. This notebook demonstrates how to provide a basic understanding of how these models process sequences and generate output. It builds upon the concepts of word embeddings and sequential modeling introduced by earlier models like Word2Vec.

# %% [markdown]
# ## Alternative Examples you could create with this type of Encoder-Decoder architecture with RNNs

# %% [markdown]
# Here are some alternative examples that can be used to showcase the Encoder-Decoder architecture with RNNs. Each of these examples is designed to highlight different aspects of sequence-to-sequence learning, such as translation, transformation, or summarization.
#
# ### 1. **Date Format Conversion**
#    - **Task**: Convert dates from one format to another.
#    - **Input**: "01-01-2024"
#    - **Output**: "January 1, 2024"
#    - **Purpose**: This task demonstrates how the Encoder-Decoder model can learn to map a structured input sequence to a more natural language output format.
#    - **Benefits**:
#      - Shows the model’s ability to understand and generate different sequence patterns.
#      - Useful for practical applications like data preprocessing and natural language understanding.
#
# ### 2. **Math Equation to Verbal Description**
#    - **Task**: Convert simple arithmetic equations into their word forms.
#    - **Input**: "3 + 5"
#    - **Output**: "three plus five equals eight"
#    - **Purpose**: Demonstrates the model's ability to interpret and generate sequences based on arithmetic logic.
#    - **Benefits**:
#      - Highlights how sequence-to-sequence models can be used for educational tools.
#      - Illustrates the model’s capability to understand numerical context.
#
# ### 3. **Reversing Sentences**
#    - **Task**: Reverse the words in a sentence.
#    - **Input**: "The quick brown fox"
#    - **Output**: "fox brown quick The"
#    - **Purpose**: A simple task to demonstrate the model’s ability to handle sequence manipulation.
#    - **Benefits**:
#      - Provides an easy-to-understand example of sequence transformation.
#      - Can be a starting point for understanding more complex tasks like summarization.
#
# ### 4. **Translation of Phrases**
#    - **Task**: Translate short phrases from one language to another.
#    - **Input**: "Good morning"
#    - **Output**: "Buenos días"
#    - **Purpose**: Shows the Encoder-Decoder model’s strength in handling language translation.
#    - **Benefits**:
#      - Directly applicable to real-world use cases like language translation services.
#      - Illustrates the model's understanding of context and semantics.
#
# ### 5. **Text Summarization**
#    - **Task**: Summarize longer sentences into shorter phrases.
#    - **Input**: "The quick brown fox jumps over the lazy dog because it was feeling very energetic and playful."
#    - **Output**: "Energetic fox jumps."
#    - **Purpose**: Demonstrates how the Encoder-Decoder architecture can be used for text summarization by learning to capture the essence of a longer text.
#    - **Benefits**:
#      - Useful for creating more advanced applications in text processing.
#      - Showcases the ability to condense information while preserving meaning.
#
# ### 6. **Sequence Number Mapping**
#    - **Task**: Map a sequence of numbers to a verbal description.
#    - **Input**: "123"
#    - **Output**: "one hundred twenty-three"
#    - **Purpose**: Demonstrates how the model can handle digit-to-word conversion, useful in various applications such as voice assistants.
#    - **Benefits**:
#      - Highlights the model's ability to understand and verbalize numerical data.
#      - Useful for building interactive voice-based systems.
#
# ### Selecting an Alternative Example:
# - **Complexity**: Choose an example that matches the complexity level you're comfortable with and want to demonstrate. Simple tasks like reversing sentences are easier to implement, while summarization or translation can be more complex.
# - **Application**: Consider the real-world applicability of the task. For instance, translation and date format conversion are common use cases that resonate well with practical applications.
# - **Demonstration**: If the goal is to show the model's capability in understanding context and generating coherent outputs, translation and summarization are good choices.
#
# ### Recommended Example for Implementation:
# Given the previous translation example in the notebook, **Date Format Conversion** can be a suitable next step. It's simple yet effective in demonstrating how an Encoder-Decoder model can handle structured data and convert it into a natural language format, which can be particularly illustrative for those new to sequence-to-sequence modeling.

# %% [markdown]
# TODO: Show architecture

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# #### Step 2: Define the Dataset
# Let's define a small dataset of date conversions. For simplicity, we'll use a few examples:

# %%
# Define a simple dataset with start and end tokens
input_dates = [
    "01-01-2024",
    "02-14-2024",
    "12-25-2023",
    "07-04-2024",
    "11-11-2023",
    "10-31-2024"
]

output_dates = [
    "<start> January 1, 2024 <end>",
    "<start> February 14, 2024 <end>",
    "<start> December 25, 2023 <end>",
    "<start> July 4, 2024 <end>",
    "<start> November 11, 2023 <end>",
    "<start> October 31, 2024 <end>"
]

# Create character sets
input_characters = sorted(set(''.join(input_dates)))
output_characters = sorted(set(''.join(output_dates)))

# Make sure to include '<start>' and '<end>' in the character set
output_characters.extend(['<start>', '<end>'])
output_characters = sorted(set(output_characters))

num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(output_characters)

# Create a mapping of characters to integers
input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
output_token_index = dict([(char, i) for i, char in enumerate(output_characters)])

reverse_output_token_index = dict((i, char) for char, i in output_token_index.items())

# %% [markdown]
# #### Step 3: Preprocess the Data
# Convert the dates into a format suitable for training the model.

# %%
# Define maximum sequence lengths
max_encoder_seq_length = max([len(txt) for txt in input_dates])
max_decoder_seq_length = max([len(txt) for txt in output_dates])

# Vectorize the input and output dates
encoder_input_data = np.zeros((len(input_dates), max_encoder_seq_length, num_encoder_tokens), dtype='float32')
decoder_input_data = np.zeros((len(output_dates), max_decoder_seq_length, num_decoder_tokens), dtype='float32')
decoder_target_data = np.zeros((len(output_dates), max_decoder_seq_length, num_decoder_tokens), dtype='float32')

for i, (input_text, target_text) in enumerate(zip(input_dates, output_dates)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    for t, char in enumerate(target_text):
        decoder_input_data[i, t, output_token_index[char]] = 1.0
        if t > 0:
            decoder_target_data[i, t - 1, output_token_index[char]] = 1.0

# %% [markdown]
# #### Step 4: Build the Encoder-Decoder Model

# %%
from tensorflow.keras.layers import Dropout

# Define the Encoder
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder_lstm = LSTM(256, return_state=True, recurrent_dropout=0.2)  # Add dropout
encoder_outputs, state_h, state_c = encoder_lstm(encoder_inputs)
encoder_states = [state_h, state_c]

# Define the Decoder
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(256, return_sequences=True, return_state=True, recurrent_dropout=0.2)  # Add dropout
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #### Step 5: Train the Model

# %%
# Reset stdout to default
#sys.stdout = sys.__stdout__

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
#%%capture training_output
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=64,
          epochs=500,  # Set a higher maximum but rely on early stopping
          validation_split=0.2,
          verbose=2,  # One line per epoch
          callbacks=[early_stopping])
# Out:
# Epoch 1/500
# 1/1 - 4s - 4s/step - accuracy: 0.0000e+00 - loss: 3.1584 - val_accuracy: 0.2097 - val_loss: 3.2701
# Epoch 2/500
# 1/1 - 0s - 111ms/step - accuracy: 0.2581 - loss: 3.1276 - val_accuracy: 0.2419 - val_loss: 3.2455
# Epoch 3/500
# 1/1 - 0s - 114ms/step - accuracy: 0.2823 - loss: 3.0970 - val_accuracy: 0.2419 - val_loss: 3.2145
# Epoch 4/500
# 1/1 - 0s - 96ms/step - accuracy: 0.2661 - loss: 3.0617 - val_accuracy: 0.2258 - val_loss: 3.1612
# Epoch 5/500
# 1/1 - 0s - 93ms/step - accuracy: 0.2581 - loss: 3.0023 - val_accuracy: 0.2097 - val_loss: 3.0359
# Epoch 6/500
# 1/1 - 0s - 94ms/step - accuracy: 0.2500 - loss: 2.8654 - val_accuracy: 0.1774 - val_loss: 2.9446
# Epoch 7/500
# 1/1 - 0s - 92ms/step - accuracy: 0.2177 - loss: 2.7456 - val_accuracy: 0.1290 - val_loss: 2.9588
# Epoch 8/500
# 1/1 - 0s - 94ms/step - accuracy: 0.1532 - loss: 2.7655 - val_accuracy: 0.2097 - val_loss: 2.8779
# Epoch 9/500
# 1/1 - 0s - 90ms/step - accuracy: 0.2500 - loss: 2.6418 - val_accuracy: 0.2097 - val_loss: 2.8617
# Epoch 10/500
# 1/1 - 0s - 86ms/step - accuracy: 0.2500 - loss: 2.6077 - val_accuracy: 0.1774 - val_loss: 2.8218
# Epoch 11/500
# 1/1 - 0s - 89ms/step - accuracy: 0.1613 - loss: 2.5531 - val_accuracy: 0.2097 - val_loss: 2.7698
# Epoch 12/500
# 1/1 - 0s - 86ms/step - accuracy: 0.2581 - loss: 2.4844 - val_accuracy: 0.1613 - val_loss: 2.7523
# Epoch 13/500
# 1/1 - 0s - 100ms/step - accuracy: 0.1532 - loss: 2.4209 - val_accuracy: 0.2097 - val_loss: 2.7988
# Epoch 14/500
# 1/1 - 0s - 104ms/step - accuracy: 0.2661 - loss: 2.5555 - val_accuracy: 0.1129 - val_loss: 2.8592
# Epoch 15/500
# 1/1 - 0s - 93ms/step - accuracy: 0.1532 - loss: 2.5010 - val_accuracy: 0.2419 - val_loss: 2.7148
# Epoch 16/500
# 1/1 - 0s - 85ms/step - accuracy: 0.2742 - loss: 2.3725 - val_accuracy: 0.2419 - val_loss: 2.6646
# Epoch 17/500
# 1/1 - 0s - 93ms/step - accuracy: 0.2419 - loss: 2.3066 - val_accuracy: 0.2258 - val_loss: 2.6067
# Epoch 18/500
# 1/1 - 0s - 89ms/step - accuracy: 0.2581 - loss: 2.2487 - val_accuracy: 0.2258 - val_loss: 2.6135
# Epoch 19/500
# 1/1 - 0s - 92ms/step - accuracy: 0.2097 - loss: 2.2127 - val_accuracy: 0.2419 - val_loss: 2.5432
# Epoch 20/500
# 1/1 - 0s - 92ms/step - accuracy: 0.2500 - loss: 2.2139 - val_accuracy: 0.2097 - val_loss: 2.6620
# Epoch 21/500
# 1/1 - 0s - 97ms/step - accuracy: 0.2742 - loss: 2.2472 - val_accuracy: 0.2742 - val_loss: 2.5190
# Epoch 22/500
# 1/1 - 0s - 90ms/step - accuracy: 0.2581 - loss: 2.1666 - val_accuracy: 0.2258 - val_loss: 2.6173
# Epoch 23/500
# 1/1 - 0s - 89ms/step - accuracy: 0.2581 - loss: 2.1641 - val_accuracy: 0.2742 - val_loss: 2.4753
# Epoch 24/500
# 1/1 - 0s - 93ms/step - accuracy: 0.2984 - loss: 2.0921 - val_accuracy: 0.2742 - val_loss: 2.5687
# Epoch 25/500
# 1/1 - 0s - 94ms/step - accuracy: 0.2500 - loss: 2.1157 - val_accuracy: 0.2742 - val_loss: 2.4433
# Epoch 26/500
# 1/1 - 0s - 102ms/step - accuracy: 0.2661 - loss: 2.0840 - val_accuracy: 0.1935 - val_loss: 2.6216
# Epoch 27/500
# 1/1 - 0s - 104ms/step - accuracy: 0.2339 - loss: 2.1039 - val_accuracy: 0.2742 - val_loss: 2.4366
# Epoch 28/500
# 1/1 - 0s - 127ms/step - accuracy: 0.3065 - loss: 2.0228 - val_accuracy: 0.2903 - val_loss: 2.5376
# Epoch 29/500
# 1/1 - 0s - 128ms/step - accuracy: 0.2823 - loss: 2.0092 - val_accuracy: 0.2903 - val_loss: 2.3825
# Epoch 30/500
# 1/1 - 0s - 88ms/step - accuracy: 0.2742 - loss: 1.9776 - val_accuracy: 0.2258 - val_loss: 2.5815
# Epoch 31/500
# 1/1 - 0s - 91ms/step - accuracy: 0.2419 - loss: 2.0185 - val_accuracy: 0.2742 - val_loss: 2.4007
# Epoch 32/500
# 1/1 - 0s - 95ms/step - accuracy: 0.3387 - loss: 1.9805 - val_accuracy: 0.1613 - val_loss: 2.5811
# Epoch 33/500
# 1/1 - 0s - 95ms/step - accuracy: 0.2419 - loss: 2.0099 - val_accuracy: 0.2742 - val_loss: 2.3636
# Epoch 34/500
# 1/1 - 0s - 92ms/step - accuracy: 0.2984 - loss: 1.9957 - val_accuracy: 0.1774 - val_loss: 2.6307
# Epoch 35/500
# 1/1 - 0s - 90ms/step - accuracy: 0.2097 - loss: 2.0659 - val_accuracy: 0.3226 - val_loss: 2.3318
# Epoch 36/500
# 1/1 - 0s - 87ms/step - accuracy: 0.3468 - loss: 1.9063 - val_accuracy: 0.2903 - val_loss: 2.4152
# Epoch 37/500
# 1/1 - 0s - 91ms/step - accuracy: 0.3145 - loss: 1.8507 - val_accuracy: 0.3226 - val_loss: 2.2983
# Epoch 38/500
# 1/1 - 0s - 92ms/step - accuracy: 0.2903 - loss: 1.8910 - val_accuracy: 0.2258 - val_loss: 2.5648
# Epoch 39/500
# 1/1 - 0s - 95ms/step - accuracy: 0.2742 - loss: 1.9548 - val_accuracy: 0.2742 - val_loss: 2.2972
# Epoch 40/500
# 1/1 - 0s - 88ms/step - accuracy: 0.3306 - loss: 1.8446 - val_accuracy: 0.2419 - val_loss: 2.4490
# Epoch 41/500
# 1/1 - 0s - 98ms/step - accuracy: 0.3065 - loss: 1.8167 - val_accuracy: 0.3226 - val_loss: 2.2686
# Epoch 42/500
# 1/1 - 0s - 87ms/step - accuracy: 0.3065 - loss: 1.7963 - val_accuracy: 0.2097 - val_loss: 2.4851
# Epoch 43/500
# 1/1 - 0s - 87ms/step - accuracy: 0.2742 - loss: 1.8577 - val_accuracy: 0.3226 - val_loss: 2.2497
# Epoch 44/500
# 1/1 - 0s - 89ms/step - accuracy: 0.3065 - loss: 1.8281 - val_accuracy: 0.1935 - val_loss: 2.6820
# Epoch 45/500
# 1/1 - 0s - 97ms/step - accuracy: 0.2742 - loss: 1.9980 - val_accuracy: 0.3387 - val_loss: 2.2604
# Epoch 46/500
# 1/1 - 0s - 99ms/step - accuracy: 0.3387 - loss: 1.7868 - val_accuracy: 0.2581 - val_loss: 2.4265
# Epoch 47/500
# 1/1 - 0s - 97ms/step - accuracy: 0.3790 - loss: 1.7627 - val_accuracy: 0.3387 - val_loss: 2.2262
# Epoch 48/500
# 1/1 - 0s - 89ms/step - accuracy: 0.2903 - loss: 1.7918 - val_accuracy: 0.2097 - val_loss: 2.5577
# Epoch 49/500
# 1/1 - 0s - 88ms/step - accuracy: 0.2984 - loss: 1.8933 - val_accuracy: 0.3387 - val_loss: 2.2188
# Epoch 50/500
# 1/1 - 0s - 89ms/step - accuracy: 0.3548 - loss: 1.8038 - val_accuracy: 0.2742 - val_loss: 2.4993
# Epoch 51/500
# 1/1 - 0s - 87ms/step - accuracy: 0.3387 - loss: 1.7901 - val_accuracy: 0.3548 - val_loss: 2.2281
# Epoch 52/500
# 1/1 - 0s - 95ms/step - accuracy: 0.3468 - loss: 1.7238 - val_accuracy: 0.2581 - val_loss: 2.4305
# Epoch 53/500
# 1/1 - 0s - 99ms/step - accuracy: 0.3629 - loss: 1.6903 - val_accuracy: 0.3548 - val_loss: 2.2035
# Epoch 54/500
# 1/1 - 0s - 88ms/step - accuracy: 0.3065 - loss: 1.6859 - val_accuracy: 0.2097 - val_loss: 2.5401
# Epoch 55/500
# 1/1 - 0s - 88ms/step - accuracy: 0.3226 - loss: 1.7738 - val_accuracy: 0.3710 - val_loss: 2.2082
# Epoch 56/500
# 1/1 - 0s - 91ms/step - accuracy: 0.3145 - loss: 1.7505 - val_accuracy: 0.2903 - val_loss: 2.4397
# Epoch 57/500
# 1/1 - 0s - 91ms/step - accuracy: 0.3387 - loss: 1.7063 - val_accuracy: 0.3710 - val_loss: 2.1882
# Epoch 58/500
# 1/1 - 0s - 89ms/step - accuracy: 0.3790 - loss: 1.6136 - val_accuracy: 0.3548 - val_loss: 2.2399
# Epoch 59/500
# 1/1 - 0s - 98ms/step - accuracy: 0.3468 - loss: 1.5942 - val_accuracy: 0.4355 - val_loss: 2.2000
# Epoch 60/500
# 1/1 - 0s - 97ms/step - accuracy: 0.4274 - loss: 1.6108 - val_accuracy: 0.2903 - val_loss: 2.2919
# Epoch 61/500
# 1/1 - 0s - 99ms/step - accuracy: 0.3387 - loss: 1.6456 - val_accuracy: 0.3871 - val_loss: 2.1748
# Epoch 62/500
# 1/1 - 0s - 109ms/step - accuracy: 0.3871 - loss: 1.6666 - val_accuracy: 0.2419 - val_loss: 2.7004
# Epoch 63/500
# 1/1 - 0s - 102ms/step - accuracy: 0.2903 - loss: 1.8333 - val_accuracy: 0.3710 - val_loss: 2.1869
# Epoch 64/500
# 1/1 - 0s - 94ms/step - accuracy: 0.3629 - loss: 1.6759 - val_accuracy: 0.2742 - val_loss: 2.4679
# Epoch 65/500
# 1/1 - 0s - 105ms/step - accuracy: 0.3548 - loss: 1.6823 - val_accuracy: 0.4355 - val_loss: 2.1602
# Epoch 66/500
# 1/1 - 0s - 109ms/step - accuracy: 0.3790 - loss: 1.6427 - val_accuracy: 0.3065 - val_loss: 2.4504
# Epoch 67/500
# 1/1 - 0s - 106ms/step - accuracy: 0.3871 - loss: 1.6795 - val_accuracy: 0.3871 - val_loss: 2.1428
# Epoch 68/500
# 1/1 - 0s - 110ms/step - accuracy: 0.4194 - loss: 1.6036 - val_accuracy: 0.3387 - val_loss: 2.3052
# Epoch 69/500
# 1/1 - 0s - 100ms/step - accuracy: 0.4113 - loss: 1.5797 - val_accuracy: 0.3548 - val_loss: 2.1769
# Epoch 70/500
# 1/1 - 0s - 87ms/step - accuracy: 0.3871 - loss: 1.6161 - val_accuracy: 0.3226 - val_loss: 2.4837
# Epoch 71/500
# 1/1 - 0s - 90ms/step - accuracy: 0.3790 - loss: 1.6714 - val_accuracy: 0.4194 - val_loss: 2.1336
# Epoch 72/500
# 1/1 - 0s - 89ms/step - accuracy: 0.3226 - loss: 1.6107 - val_accuracy: 0.3387 - val_loss: 2.3342
# Epoch 73/500
# 1/1 - 0s - 88ms/step - accuracy: 0.4032 - loss: 1.5814 - val_accuracy: 0.5000 - val_loss: 2.1161
# Epoch 74/500
# 1/1 - 0s - 96ms/step - accuracy: 0.4355 - loss: 1.5129 - val_accuracy: 0.3387 - val_loss: 2.3053
# Epoch 75/500
# 1/1 - 0s - 93ms/step - accuracy: 0.4355 - loss: 1.5122 - val_accuracy: 0.4839 - val_loss: 2.1090
# Epoch 76/500
# 1/1 - 0s - 98ms/step - accuracy: 0.4194 - loss: 1.4830 - val_accuracy: 0.3710 - val_loss: 2.2506
# Epoch 77/500
# 1/1 - 0s - 91ms/step - accuracy: 0.4597 - loss: 1.4515 - val_accuracy: 0.4194 - val_loss: 2.1539
# Epoch 78/500
# 1/1 - 0s - 95ms/step - accuracy: 0.4516 - loss: 1.4943 - val_accuracy: 0.4839 - val_loss: 2.0828
# Epoch 79/500
# 1/1 - 0s - 85ms/step - accuracy: 0.4597 - loss: 1.4577 - val_accuracy: 0.3065 - val_loss: 2.4801
# Epoch 80/500
# 1/1 - 0s - 88ms/step - accuracy: 0.3952 - loss: 1.6168 - val_accuracy: 0.2903 - val_loss: 2.1998
# Epoch 81/500
# 1/1 - 0s - 97ms/step - accuracy: 0.3065 - loss: 1.7668 - val_accuracy: 0.2258 - val_loss: 2.7363
# Epoch 82/500
# 1/1 - 0s - 96ms/step - accuracy: 0.3145 - loss: 1.9156 - val_accuracy: 0.4194 - val_loss: 2.1086
# Epoch 83/500
# 1/1 - 0s - 98ms/step - accuracy: 0.4435 - loss: 1.5694 - val_accuracy: 0.3387 - val_loss: 2.2254
# Epoch 84/500
# 1/1 - 0s - 98ms/step - accuracy: 0.4274 - loss: 1.5223 - val_accuracy: 0.4194 - val_loss: 2.0790
# Epoch 85/500
# 1/1 - 0s - 89ms/step - accuracy: 0.4516 - loss: 1.4644 - val_accuracy: 0.3871 - val_loss: 2.1313
# Epoch 86/500
# 1/1 - 0s - 95ms/step - accuracy: 0.4355 - loss: 1.4468 - val_accuracy: 0.5161 - val_loss: 2.0413
# Epoch 87/500
# 1/1 - 0s - 88ms/step - accuracy: 0.4919 - loss: 1.4239 - val_accuracy: 0.4032 - val_loss: 2.1374
# Epoch 88/500
# 1/1 - 0s - 85ms/step - accuracy: 0.4516 - loss: 1.4128 - val_accuracy: 0.5000 - val_loss: 2.0602
# Epoch 89/500
# 1/1 - 0s - 89ms/step - accuracy: 0.4355 - loss: 1.4715 - val_accuracy: 0.2903 - val_loss: 2.4527
# Epoch 90/500
# 1/1 - 0s - 97ms/step - accuracy: 0.3871 - loss: 1.6341 - val_accuracy: 0.3710 - val_loss: 2.1407
# Epoch 91/500
# 1/1 - 0s - 93ms/step - accuracy: 0.3790 - loss: 1.5604 - val_accuracy: 0.3226 - val_loss: 2.4467
# Epoch 92/500
# 1/1 - 0s - 95ms/step - accuracy: 0.3952 - loss: 1.6411 - val_accuracy: 0.4677 - val_loss: 2.0847
# Epoch 93/500
# 1/1 - 0s - 89ms/step - accuracy: 0.4516 - loss: 1.5185 - val_accuracy: 0.3387 - val_loss: 2.2373
# Epoch 94/500
# 1/1 - 0s - 87ms/step - accuracy: 0.4032 - loss: 1.4868 - val_accuracy: 0.5161 - val_loss: 2.0541
# Epoch 95/500
# 1/1 - 0s - 97ms/step - accuracy: 0.4597 - loss: 1.4610 - val_accuracy: 0.3226 - val_loss: 2.3235
# Epoch 96/500
# 1/1 - 0s - 100ms/step - accuracy: 0.4597 - loss: 1.4659 - val_accuracy: 0.5000 - val_loss: 2.0407
# Epoch 97/500
# 1/1 - 0s - 109ms/step - accuracy: 0.4758 - loss: 1.3901 - val_accuracy: 0.4032 - val_loss: 2.1101
# Epoch 98/500
# 1/1 - 0s - 104ms/step - accuracy: 0.4274 - loss: 1.4251 - val_accuracy: 0.5000 - val_loss: 2.0325
# Epoch 99/500
# 1/1 - 0s - 95ms/step - accuracy: 0.4516 - loss: 1.3953 - val_accuracy: 0.3226 - val_loss: 2.5137
# Epoch 100/500
# 1/1 - 0s - 94ms/step - accuracy: 0.3548 - loss: 1.6464 - val_accuracy: 0.4839 - val_loss: 2.1027
# Epoch 101/500
# 1/1 - 0s - 96ms/step - accuracy: 0.4758 - loss: 1.4449 - val_accuracy: 0.3387 - val_loss: 2.2292
# Epoch 102/500
# 1/1 - 0s - 103ms/step - accuracy: 0.4355 - loss: 1.4311 - val_accuracy: 0.5000 - val_loss: 2.0040
# Epoch 103/500
# 1/1 - 0s - 89ms/step - accuracy: 0.5081 - loss: 1.4490 - val_accuracy: 0.3226 - val_loss: 2.2856
# Epoch 104/500
# 1/1 - 0s - 91ms/step - accuracy: 0.4032 - loss: 1.4813 - val_accuracy: 0.5161 - val_loss: 1.9935
# Epoch 105/500
# 1/1 - 0s - 88ms/step - accuracy: 0.4839 - loss: 1.3989 - val_accuracy: 0.3226 - val_loss: 2.2404
# Epoch 106/500
# 1/1 - 0s - 87ms/step - accuracy: 0.4677 - loss: 1.4011 - val_accuracy: 0.4516 - val_loss: 2.0085
# Epoch 107/500
# 1/1 - 0s - 88ms/step - accuracy: 0.4516 - loss: 1.3431 - val_accuracy: 0.3548 - val_loss: 2.1236
# Epoch 108/500
# 1/1 - 0s - 95ms/step - accuracy: 0.4919 - loss: 1.3212 - val_accuracy: 0.4677 - val_loss: 2.0233
# Epoch 109/500
# 1/1 - 0s - 95ms/step - accuracy: 0.4758 - loss: 1.3204 - val_accuracy: 0.4194 - val_loss: 2.0606
# Epoch 110/500
# 1/1 - 0s - 92ms/step - accuracy: 0.4758 - loss: 1.3114 - val_accuracy: 0.4677 - val_loss: 1.9896
# Epoch 111/500
# 1/1 - 0s - 89ms/step - accuracy: 0.4597 - loss: 1.3142 - val_accuracy: 0.3548 - val_loss: 2.1782
# Epoch 112/500
# 1/1 - 0s - 94ms/step - accuracy: 0.4516 - loss: 1.3373 - val_accuracy: 0.3548 - val_loss: 2.1894
# Epoch 113/500
# 1/1 - 0s - 105ms/step - accuracy: 0.3952 - loss: 1.5301 - val_accuracy: 0.2419 - val_loss: 2.6789
# Epoch 114/500
# 1/1 - 0s - 162ms/step - accuracy: 0.3226 - loss: 1.7824 - val_accuracy: 0.4516 - val_loss: 2.0190
# Epoch 115/500
# 1/1 - 0s - 103ms/step - accuracy: 0.4355 - loss: 1.4016 - val_accuracy: 0.3710 - val_loss: 2.1141
# Epoch 116/500
# 1/1 - 0s - 94ms/step - accuracy: 0.5081 - loss: 1.3567 - val_accuracy: 0.5323 - val_loss: 1.9537
# Epoch 117/500
# 1/1 - 0s - 86ms/step - accuracy: 0.5000 - loss: 1.3319 - val_accuracy: 0.3548 - val_loss: 2.1613
# Epoch 118/500
# 1/1 - 0s - 91ms/step - accuracy: 0.4839 - loss: 1.3142 - val_accuracy: 0.5161 - val_loss: 1.9542
# Epoch 119/500
# 1/1 - 0s - 89ms/step - accuracy: 0.5242 - loss: 1.2945 - val_accuracy: 0.3871 - val_loss: 2.0508
# Epoch 120/500
# 1/1 - 0s - 85ms/step - accuracy: 0.4516 - loss: 1.2926 - val_accuracy: 0.3871 - val_loss: 2.1195
# Epoch 121/500
# 1/1 - 0s - 84ms/step - accuracy: 0.3952 - loss: 1.5399 - val_accuracy: 0.3065 - val_loss: 2.5154
# Epoch 122/500
# 1/1 - 0s - 99ms/step - accuracy: 0.3871 - loss: 1.6019 - val_accuracy: 0.4516 - val_loss: 1.9809
# Epoch 123/500
# 1/1 - 0s - 92ms/step - accuracy: 0.4597 - loss: 1.3585 - val_accuracy: 0.3871 - val_loss: 2.0874
# Epoch 124/500
# 1/1 - 0s - 87ms/step - accuracy: 0.4597 - loss: 1.3489 - val_accuracy: 0.5323 - val_loss: 1.9739
# Epoch 125/500
# 1/1 - 0s - 88ms/step - accuracy: 0.5081 - loss: 1.3055 - val_accuracy: 0.4194 - val_loss: 2.0564
# Epoch 126/500
# 1/1 - 0s - 84ms/step - accuracy: 0.5161 - loss: 1.2514 - val_accuracy: 0.4677 - val_loss: 1.9898

# %%
# print out results of training
#print(training_output.stdout)

# %% [markdown]
# #### Step 6: Define Inference Models for Prediction

# %%
# Define the encoder model for inference
encoder_model = Model(encoder_inputs, encoder_states)

# Define the decoder model for inference
decoder_state_input_h = Input(shape=(256,))
decoder_state_input_c = Input(shape=(256,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %% [markdown]
# #### Step 7: Generate Sequences

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1 with the start token
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0, 0, output_token_index['<start>']] = 1.0

    # Sampling loop for a batch of sequences
    stop_condition = False
    decoded_sentence = ''
    max_decoder_seq_length = 50  # Set a maximum length for the decoded sequence
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_output_token_index[sampled_token_index]

        # Check for end token
        if sampled_char == '<end>':
            stop_condition = True
        else:
            decoded_sentence += sampled_char

        # Break the loop if it reaches max length
        if len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (length 1)
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]

    return decoded_sentence.strip()  # Strip any leading/trailing whitespace

# Test the model
for seq_index in range(len(input_dates)):
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input:', input_dates[seq_index])
    print('Decoded:', decoded_sentence)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# -
# Input: 01-01-2024
# Decoded: start>  Jeuarry  222222 <een>>>>>>>>>>>>>>>>>>>>>>>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# -
# Input: 02-14-2024
# Decoded: start>  Jeuarrr  222222 <een>>>>>>>>>>>>>>>>>>>>>>>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# -
# Input: 12-25-2023
# Decoded: start>  Jeuarrr  2222222<een>>>>>>>>>>>>>>>>>>>>>>>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# -
# Input: 07-04-2024
# Decoded: start> Jeeuarr  2222222<<end>>>>>>>>>>>>>>>>>>>>>>>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# -
# Input: 11-11-2023
# Decoded: start>  Jeuarrr  2222222<een>>>>>>>>>>>>>>>>>>>>>>>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# -
# Input: 10-31-2024
# Decoded: start>  Jeuarrr  222222 <een>>>>>>>>>>>>>>>>>>>>>>>

# %% [markdown]
# ### Explanation:
# - Data Preparation: The dates are encoded into one-hot vectors for both input and output.
# - Model Training: We train an LSTM-based Encoder-Decoder model to learn the mapping between the date formats.
# - Inference: We use the trained model to decode and predict the natural language format of the dates.
#
# ### Conclusion:
# This notebook demonstrates how an Encoder-Decoder architecture can be used for the task of converting dates from a numerical format to a more natural language format. It highlights the model's ability to learn and generate sequences, showcasing the power of RNN-based Encoder-Decoder models for sequence-to-sequence tasks.
